# %% [markdown]
# <a href="https://colab.research.google.com/github/Polineska/VCR-HR-platform/blob/main/Employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10

# %%
import numpy as np
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from catboost import CatBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
drive.mount("/content/drive")
df = pd.read_csv("/content/drive/MyDrive/4 курс/ВКР/Employee.csv")
print("Размер датасета:", df.shape)
df.head()
# Out:
# Mounted at /content/drive
# Размер датасета: (4653, 9)
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.describe(include='all')
# Out:
#         Education  JoiningYear       City  PaymentTier          Age Gender  \
# count        4653  4653.000000       4653  4653.000000  4653.000000   4653
# unique          3          NaN          3          NaN          NaN      2
# top     Bachelors          NaN  Bangalore          NaN          NaN   Male
# freq         3601          NaN       2228          NaN          NaN   2778
# mean          NaN  2015.062970        NaN     2.698259    29.393295    NaN
# std           NaN     1.863377        NaN     0.561435     4.826087    NaN
# min           NaN  2012.000000        NaN     1.000000    22.000000    NaN
# 25%           NaN  2013.000000        NaN     3.000000    26.000000    NaN
# 50%           NaN  2015.000000        NaN     3.000000    28.000000    NaN
# 75%           NaN  2017.000000        NaN     3.000000    32.000000    NaN
# max           NaN  2018.000000        NaN     3.000000    41.000000    NaN
#
#        EverBenched  ExperienceInCurrentDomain   LeaveOrNot
# count         4653                4653.000000  4653.000000
# unique           2                        NaN          NaN
# top             No                        NaN          NaN
# freq          4175                        NaN          NaN
# mean           NaN                   2.905652     0.343864
# std            NaN                   1.558240     0.475047
# min            NaN                   0.000000     0.000000
# 25%            NaN                   2.000000     0.000000
# 50%            NaN                   3.000000     0.000000
# 75%            NaN                   4.000000     1.000000
# max            NaN                   7.000000     1.000000

# %%
# Проверка пропусков
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
#прверка количества дубликатов
df.duplicated().sum()
# Out:
# np.int64(1889)

# %%
#очистим датсет от дубликатов
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.reset_index(drop=True)
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %% [markdown]
# Анализ датасета

# %%
df['JoiningYear'].value_counts()
# Out:
# JoiningYear
# 2017    662
# 2015    464
# 2013    396
# 2014    385
# 2016    310
# 2012    308
# 2018    239
# Name: count, dtype: int64

# %%
num_cols = ["Age", "ExperienceInCurrentDomain"]

for col in num_cols:
    plt.figure(figsize=(7,4))
    plt.hist(df[col], bins=20)
    plt.title(f"Распределение {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
df['Age'].describe()
# Out:
# count    2764.000000
# mean       30.952967
# std         5.108872
# min        22.000000
# 25%        27.000000
# 50%        30.000000
# 75%        35.000000
# max        41.000000
# Name: Age, dtype: float64

# %% [markdown]
# Большинство сотрудников находятся в возрастном диапазоне от 25 до 28 лет, что указывает на относительно молодую рабочую силу.Большинство сотрудников имеют опыт работы в своей текущей области до 5 лет, а максимальный стаж составляет около 2 лет.

# %%
plt.figure(figsize=(14,5))
plt.pie(x=df['City'].value_counts(),labels=df['City'].value_counts().index,autopct="%1.2f%%")
plt.title("Распеределение по городам")
plt.show()

# %% [markdown]
# Большинство сотрудников работают в Bangalore

# %%
payment_tier_distribution = df['PaymentTier'].value_counts(normalize=True) * 100

plt.figure(figsize=(7, 5))
payment_tier_distribution.plot(kind='bar')
plt.title('Распределение уровней оплаты')
plt.xlabel('Payment Tier')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Большинство имеют высокий, 3 уровень оплаты

# %%
df['LeaveOrNot'].value_counts()
# Out:
# LeaveOrNot
# 0    1676
# 1    1088
# Name: count, dtype: int64

# %%
num_employees_left = df['LeaveOrNot'].sum()
print(f"Количество уволенных сотрудников: {num_employees_left}")
# Out:
# Количество уволенных сотрудников: 1088

# %%
plt.figure(figsize=(14,5))
plt.pie(x=df['EverBenched'].value_counts(),labels=df['EverBenched'].value_counts().index,autopct="%1.2f%%")
plt.title("EverBenched Pie Chart")
plt.show()

# %% [markdown]
# Большинство сотрудников никогда не были без работы

# %%
#Зависимость уровня образования от увольнения
df.groupby('Education')['LeaveOrNot'].value_counts()
# Out:
# Education  LeaveOrNot
# Bachelors  0             1232
#            1              739
# Masters    0              328
#            1              309
# PHD        0              116
#            1               40
# Name: count, dtype: int64

# %%
#Зависимость года приянтия от увольнения
df.groupby('LeaveOrNot')['JoiningYear'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  JoiningYear
# 0           2017           27.505967
#             2015           16.229117
#             2014           15.871122
#             2012           13.424821
#             2013           13.424821
#             2016           13.245823
#             2018            0.298329
# 1           2018           21.507353
#             2017           18.474265
#             2015           17.647059
#             2013           15.716912
#             2014           10.937500
#             2016            8.088235
#             2012            7.628676
# Name: proportion, dtype: float64

# %%
df.groupby('LeaveOrNot')['City'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  City
# 0           Bangalore    45.405728
#             New Delhi    31.145585
#             Pune         23.448687
# 1           Bangalore    37.683824
#             Pune         37.500000
#             New Delhi    24.816176
# Name: proportion, dtype: float64

# %%
df.groupby('LeaveOrNot')['PaymentTier'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  PaymentTier
# 0           3              78.042959
#             2              13.544153
#             1               8.412888
# 1           3              61.397059
#             2              31.525735
#             1               7.077206
# Name: proportion, dtype: float64

# %%
df.groupby('LeaveOrNot')['Age'].describe()
# Out:
#              count       mean       std   min   25%   50%   75%   max
# LeaveOrNot
# 0           1676.0  31.426014  5.115258  22.0  28.0  30.0  36.0  41.0
# 1           1088.0  30.224265  5.014723  22.0  26.0  29.0  34.0  41.0

# %%
df.groupby('LeaveOrNot')['Gender'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  Gender
# 0           Male      62.947494
#             Female    37.052506
# 1           Female    56.433824
#             Male      43.566176
# Name: proportion, dtype: float64

# %%
df.groupby('LeaveOrNot')['EverBenched'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  EverBenched
# 0           No             87.947494
#             Yes            12.052506
# 1           No             85.386029
#             Yes            14.613971
# Name: proportion, dtype: float64

# %%
df.groupby('LeaveOrNot')['ExperienceInCurrentDomain'].value_counts(normalize=True)*100
# Out:
# LeaveOrNot  ExperienceInCurrentDomain
# 0           2                            23.269690
#             5                            18.496420
#             1                            16.288783
#             4                            15.393795
#             3                            15.214797
#             0                            10.620525
#             6                             0.357995
#             7                             0.357995
# 1           2                            26.746324
#             3                            18.014706
#             4                            15.349265
#             1                            14.705882
#             5                            14.705882
#             0                            10.018382
#             7                             0.275735
#             6                             0.183824
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df,x='Education',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Зависимость увольнения от возраста и степенью образования")
plt.show()

# %% [markdown]
# Возраст является фактором удержания, чем старше сотрудник, тем ниже вероятность ухода, независимо от уровня образования. Наибольшая текучесть наблюдается среди молодых специалистов с Bachelor и Master.Для Bachelors наименьшая разница в возрасте между уходящими и остающимися

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df, x='ExperienceInCurrentDomain', y='Age', hue='LeaveOrNot', palette='Set2')
plt.title("Зависимость увольнения от возраста и опыта в текущей области")
plt.show()

# %% [markdown]
# У сотрудников **с малым опытом** (0-2 года) разница в возрасте между уволившимися и оставшимися незначительна.Для **среднего опыта** сотрудники, которые уходят, как правило моложе. Медианный возраст уволившихся ниже, чем у оставшихся. Разброс возрастов у уволившихся больше, длиннее усы.
# Для **большого опыта** разница становится еще более выраженной.Чем больше опыт в текущей области, тем сильнее возраст влияет на решение об уходе. Возрастные сотрудники с большим опытом демонстрируют высокую лояльность

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df,x='EverBenched',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Зависимость увольнения от временной безработности и возраста")
plt.show()

# %% [markdown]
# Сотрудники, которые были временно без работы, в среднем моложе и чаще уходят из компании. Среди сотрудников, которые были без работы, возраст уходящих и не уходящих ближе друг к другу, что может указывать на то, что сам факт, что чкловек когда-то был без работы повышает риск ухода независимо от возраста.

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df,x='Gender',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Влияние пола и возраста на увольнение ")
plt.show()

# %% [markdown]
# Пол не оказывает особого влияния на вероятность увольнения, тогда как возраст является более значимым фактором риск ухода выше у более молодых сотрудников.

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df,x='PaymentTier',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Влияние уровня зарплаты и возраста на увольнения")
plt.show()

# %% [markdown]
# Возраст уволившихся сотрудников в целом схож. Четкой зависимости между уровнем оплаты, возрастом и фактом увольнения не выявлено

# %%
plt.figure(figsize=(14,5))
sns.boxplot(data=df,x='City',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Влияние города и возраста на увольнение")
plt.show()

# %% [markdown]
# Город проживания оказывает незначительное влияние на взаимосвязь возраста и увольнения.

# %%
plt.figure(figsize=(22,6))
sns.boxplot(data=df,x='JoiningYear',y='Age',hue='LeaveOrNot',palette='Set2')
plt.title("Влияние года начала работы и возраста на увольнение")
plt.show()

# %% [markdown]
# Возраст сотрудников в сочетании с годом начала работы оказывает ограниченное влияние на факт увольнения. В большинстве периодов увольнения чаще затрагивают более молодых сотрудников, однако эта зависимость нестабильна и меняется со временем. Для сотрудников, начавших работу в 2012–2017 годах, медианный возраст уволившихся сотрудников, как правило, ниже, чем у оставшихся. Это говорит о том, что среди более молодых сотрудников вероятность увольнения выше.В 2018 году наблюдается иная картина: медианный возраст уволившихся сотрудников выше, чем у оставшихся. Это может указывать на изменение структуры найма или условий работы в этот период.

# %% [markdown]
# Машинное обучение

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
df['Education']=encoder.fit_transform(df[['Education']])
df['City']=encoder.fit_transform(df[['City']])
df['Gender']=encoder.fit_transform(df[['Gender']])
df['EverBenched']=encoder.fit_transform(df[['EverBenched']])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0          0         2017     0            3   34       1            0
# 1          0         2013     2            1   28       0            0
# 2          0         2014     1            3   38       0            0
# 3          1         2016     0            3   27       1            0
# 4          1         2017     2            3   24       1            1
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %% [markdown]
# Целевая переменная - LeaveOrNot. Нужно разделить на признаки (x)  и на целевую переменную (y)

# %%
x = df.iloc[:, :-1]
x
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 0             0         2017     0            3   34       1            0
# 1             0         2013     2            1   28       0            0
# 2             0         2014     1            3   38       0            0
# 3             1         2016     0            3   27       1            0
# 4             1         2017     2            3   24       1            1
# ...         ...          ...   ...          ...  ...     ...          ...
# 2759          1         2017     2            2   31       0            0
# 2760          0         2016     2            3   30       1            0
# 2761          1         2013     2            2   37       1            0
# 2762          1         2018     1            3   27       1            0
# 2763          0         2012     0            3   30       1            1
#
#       ExperienceInCurrentDomain
# 0                             0
# 1                             3
# 2                             2
# 3                             5
# 4                             2
# ...                         ...
# 2759                          2
# 2760                          2
# 2761                          2
# 2762                          5
# 2763                          2
#
# [2764 rows x 8 columns]

# %%
y = df.iloc[:, -1]
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 2759    0
# 2760    0
# 2761    1
# 2762    1
# 2763    0
# Name: LeaveOrNot, Length: 2764, dtype: int64

# %% [markdown]
# Разобьем на тестовую и обучающую выборку

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# **LogisticRegression**

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model_lr.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[288,  51],
#        [143,  71]])

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 64.91862567811934

# %%
model_lr.score(X_test,y_test)*100
# Out:
# 64.91862567811934

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75       339
#            1       0.58      0.33      0.42       214
#
#     accuracy                           0.65       553
#    macro avg       0.63      0.59      0.59       553
# weighted avg       0.63      0.65      0.62       553

# %% [markdown]
# Модель логистической регрессии показала среднюю точность (0.67), но низкую полноту для класса ухода сотрудников (Recall = 0.38). В текущем виде модель пригодна лишь как базовое решение

# %% [markdown]
# **RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200,random_state=42,class_weight='balanced')
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
print(rf.score(X_train,y_train)*100)
# Out:
# 92.76345545002262

# %%
print(rf.score(X_test,y_test)*100)
# Out:
# 72.69439421338156

# %% [markdown]
# Сильный разрыв между результатами на обучающей и тестовой выборках свидетельствует о наличии переобучения, что требует дополнительной настройки гиперпараметров модели

# %%
rf_1=RandomForestClassifier(max_depth=5,n_estimators=100)
rf_1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
print(rf_1.score(X_train,y_train)*100)
# Out:
# 80.23518769787427

# %%
print(rf_1.score(X_test,y_test)*100)
# Out:
# 78.84267631103074

# %%
y_pred_rf = rf_1.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85       339
#            1       0.94      0.49      0.64       214
#
#     accuracy                           0.79       553
#    macro avg       0.84      0.73      0.75       553
# weighted avg       0.82      0.79      0.77       553

# %% [markdown]
# Модель хорошо распознаёт класс 0 (recall = 0.96), но для класса 1 точность высокая (precision = 0.90), а полнота низкая (recall = 0.52).
# Общая точность модели 77%, F1-score 0.76.

# %% [markdown]
# **XGBClassifier**

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(n_estimators=100, max_depth=3)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print(xgb.score(X_train,y_train)*100)
# Out:
# 82.94889190411578

# %%
print(xgb.score(X_test,y_test)*100)
# Out:
# 80.6509945750452

# %%
y_pred_xgb = xgb.predict(X_test)

print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86       339
#            1       0.85      0.60      0.71       214
#
#     accuracy                           0.81       553
#    macro avg       0.82      0.77      0.78       553
# weighted avg       0.81      0.81      0.80       553

# %% [markdown]
# **KNeighborsClassifier**

# %%
knn=KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
print(knn.score(X_train,y_train)*100)
# Out:
# 76.88828584350973

# %%
print(knn.score(X_test,y_test)*100)
# Out:
# 69.25858951175407

# %% [markdown]
# **SVC**

# %%
svc=SVC(C=10,kernel='linear',gamma=0.8)
svc.fit(X_train,y_train)
# Out:
# SVC(C=10, gamma=0.8, kernel='linear')

# %%
print(svc.score(X_train,y_train)*100)
# Out:
# 66.71189507010402

# %%
print(svc.score(X_test,y_test)*100)
# Out:
# 65.82278481012658

# %% [markdown]
# **CatBoostClassifier**

# %%
cat=CatBoostClassifier(max_depth=5,n_estimators=100)
cat.fit(X_train,y_train)
# Out:
# Learning rate set to 0.119419
# 0:	learn: 0.6611664	total: 46.5ms	remaining: 4.6s
# 1:	learn: 0.6347007	total: 46.9ms	remaining: 2.3s
# 2:	learn: 0.6171519	total: 47.3ms	remaining: 1.53s
# 3:	learn: 0.5932338	total: 47.7ms	remaining: 1.14s
# 4:	learn: 0.5736769	total: 48.1ms	remaining: 914ms
# 5:	learn: 0.5575465	total: 48.6ms	remaining: 761ms
# 6:	learn: 0.5483564	total: 49ms	remaining: 651ms
# 7:	learn: 0.5391127	total: 49.5ms	remaining: 569ms
# 8:	learn: 0.5301439	total: 49.9ms	remaining: 505ms
# 9:	learn: 0.5234334	total: 50.3ms	remaining: 453ms
# 10:	learn: 0.5144867	total: 50.8ms	remaining: 411ms
# 11:	learn: 0.5094778	total: 51.2ms	remaining: 376ms
# 12:	learn: 0.5049438	total: 51.7ms	remaining: 346ms
# 13:	learn: 0.5014262	total: 52.1ms	remaining: 320ms
# 14:	learn: 0.4955674	total: 52.6ms	remaining: 298ms
# 15:	learn: 0.4926846	total: 53ms	remaining: 278ms
# 16:	learn: 0.4897309	total: 53.5ms	remaining: 261ms
# 17:	learn: 0.4852728	total: 53.9ms	remaining: 246ms
# 18:	learn: 0.4831899	total: 54.4ms	remaining: 232ms
# 19:	learn: 0.4799993	total: 54.8ms	remaining: 219ms
# 20:	learn: 0.4752658	total: 55.3ms	remaining: 208ms
# 21:	learn: 0.4726107	total: 55.7ms	remaining: 197ms
# 22:	learn: 0.4680996	total: 56.2ms	remaining: 188ms
# 23:	learn: 0.4655851	total: 56.6ms	remaining: 179ms
# 24:	learn: 0.4632074	total: 57.1ms	remaining: 171ms
# 25:	learn: 0.4598113	total: 57.5ms	remaining: 164ms
# 26:	learn: 0.4586633	total: 58ms	remaining: 157ms
# 27:	learn: 0.4557207	total: 58.4ms	remaining: 150ms
# 28:	learn: 0.4525613	total: 58.8ms	remaining: 144ms
# 29:	learn: 0.4517220	total: 59.3ms	remaining: 138ms
# 30:	learn: 0.4505652	total: 59.7ms	remaining: 133ms
# 31:	learn: 0.4492347	total: 60.2ms	remaining: 128ms
# 32:	learn: 0.4478601	total: 60.6ms	remaining: 123ms
# 33:	learn: 0.4461582	total: 61.1ms	remaining: 119ms
# 34:	learn: 0.4449513	total: 62ms	remaining: 115ms
# 35:	learn: 0.4438568	total: 62.6ms	remaining: 111ms
# 36:	learn: 0.4430668	total: 63.1ms	remaining: 107ms
# 37:	learn: 0.4406678	total: 63.6ms	remaining: 104ms
# 38:	learn: 0.4395142	total: 64.1ms	remaining: 100ms
# 39:	learn: 0.4381376	total: 64.5ms	remaining: 96.8ms
# 40:	learn: 0.4362577	total: 65ms	remaining: 93.5ms
# 41:	learn: 0.4343632	total: 65.4ms	remaining: 90.3ms
# 42:	learn: 0.4336558	total: 65.9ms	remaining: 87.4ms
# 43:	learn: 0.4324562	total: 66.3ms	remaining: 84.4ms
# 44:	learn: 0.4309053	total: 66.8ms	remaining: 81.7ms
# 45:	learn: 0.4303274	total: 67.3ms	remaining: 79ms
# 46:	learn: 0.4286986	total: 67.7ms	remaining: 76.4ms
# 47:	learn: 0.4274309	total: 68.2ms	remaining: 73.9ms
# 48:	learn: 0.4263708	total: 68.7ms	remaining: 71.5ms
# 49:	learn: 0.4253596	total: 69.1ms	remaining: 69.1ms
# 50:	learn: 0.4244476	total: 69.6ms	remaining: 66.9ms
# 51:	learn: 0.4238122	total: 70ms	remaining: 64.6ms
# 52:	learn: 0.4228992	total: 70.5ms	remaining: 62.5ms
# 53:	learn: 0.4219835	total: 70.9ms	remaining: 60.4ms
# 54:	learn: 0.4211616	total: 71.4ms	remaining: 58.4ms
# 55:	learn: 0.4203353	total: 71.8ms	remaining: 56.5ms
# 56:	learn: 0.4189302	total: 72.3ms	remaining: 54.6ms
# 57:	learn: 0.4179007	total: 72.8ms	remaining: 52.7ms
# 58:	learn: 0.4174362	total: 73.2ms	remaining: 50.9ms
# 59:	learn: 0.4170370	total: 73.7ms	remaining: 49.1ms
# 60:	learn: 0.4165557	total: 74.1ms	remaining: 47.4ms
# 61:	learn: 0.4158681	total: 74.6ms	remaining: 45.7ms
# 62:	learn: 0.4152276	total: 75ms	remaining: 44.1ms
# 63:	learn: 0.4144224	total: 75.5ms	remaining: 42.4ms
# 64:	learn: 0.4135911	total: 75.9ms	remaining: 40.9ms
# 65:	learn: 0.4126536	total: 76.4ms	remaining: 39.4ms
# 66:	learn: 0.4121319	total: 76.9ms	remaining: 37.9ms
# 67:	learn: 0.4111155	total: 77.3ms	remaining: 36.4ms
# 68:	learn: 0.4104115	total: 77.8ms	remaining: 34.9ms
# 69:	learn: 0.4097890	total: 78.2ms	remaining: 33.5ms
# 70:	learn: 0.4091940	total: 78.7ms	remaining: 32.1ms
# 71:	learn: 0.4087223	total: 79.1ms	remaining: 30.8ms
# 72:	learn: 0.4079575	total: 79.6ms	remaining: 29.4ms
# 73:	learn: 0.4073524	total: 80ms	remaining: 28.1ms
# 74:	learn: 0.4065840	total: 80.5ms	remaining: 26.8ms
# 75:	learn: 0.4059912	total: 80.9ms	remaining: 25.6ms
# 76:	learn: 0.4054003	total: 81.4ms	remaining: 24.3ms
# 77:	learn: 0.4047445	total: 81.8ms	remaining: 23.1ms
# 78:	learn: 0.4040075	total: 82.3ms	remaining: 21.9ms
# 79:	learn: 0.4034553	total: 82.7ms	remaining: 20.7ms
# 80:	learn: 0.4027844	total: 83.2ms	remaining: 19.5ms
# 81:	learn: 0.4024758	total: 83.6ms	remaining: 18.4ms
# 82:	learn: 0.4019622	total: 84.1ms	remaining: 17.2ms
# 83:	learn: 0.4014702	total: 84.5ms	remaining: 16.1ms
# 84:	learn: 0.4009537	total: 85ms	remaining: 15ms
# 85:	learn: 0.4004838	total: 85.5ms	remaining: 13.9ms
# 86:	learn: 0.3998989	total: 85.9ms	remaining: 12.8ms
# 87:	learn: 0.3992443	total: 86.4ms	remaining: 11.8ms
# 88:	learn: 0.3988874	total: 86.9ms	remaining: 10.7ms
# 89:	learn: 0.3981099	total: 87.3ms	remaining: 9.7ms
# 90:	learn: 0.3978403	total: 87.8ms	remaining: 8.68ms
# 91:	learn: 0.3973863	total: 88.2ms	remaining: 7.67ms
# 92:	learn: 0.3972044	total: 88.7ms	remaining: 6.67ms
# 93:	learn: 0.3966093	total: 89.1ms	remaining: 5.69ms
# 94:	learn: 0.3962430	total: 89.6ms	remaining: 4.71ms
# 95:	learn: 0.3957940	total: 90ms	remaining: 3.75ms
# 96:	learn: 0.3954274	total: 90.5ms	remaining: 2.8ms
# 97:	learn: 0.3951050	total: 90.9ms	remaining: 1.85ms
# 98:	learn: 0.3949009	total: 91.4ms	remaining: 922us
# 99:	learn: 0.3944887	total: 91.8ms	remaining: 0us

# %%
print(cat.score(X_train,y_train)*100)
# Out:
# 83.12980551786522

# %%
print(cat.score(X_test,y_test)*100)
# Out:
# 81.91681735985533

# %% [markdown]
# Сохранение модели

# %%
import joblib

# %%
joblib.dump(cat, "catboost_model.pkl")
# Out:
# ['catboost_model.pkl']
